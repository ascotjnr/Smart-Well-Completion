# %%
# %%capture
import time
! pip install seaborn
import matplotlib as plot 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import sklearn
import seaborn as sns
from matplotlib import pyplot

# Hide Warnings
import warnings
warnings.filterwarnings("ignore")

# %config InlineBackend.figure_format='svg' # To create high resolution images
# %matplotlib inline

# %%
Predictions = pd.read_csv(r"C:\Users\Daniel\OneDrive - Universiti Teknologi PETRONAS\Desktop\Book\Smart well injection\Smart Injection\Predictions_1.csv")
Predictions.head()
# Out:
#                Date       WI_Rate  UZ_Ann_Pres  MZ_Ann_Pres  LZ_Ann_Pres  \
# 0  29/12/2016 12:00   3825.695557  6673.719238  7672.870605  6457.536133
# 1  22/11/2016 16:00  13349.909180  7447.518555  8826.564453  6497.536621
# 2   14/12/2016 1:00   5647.179688  6297.257813  8735.780273  6524.355957
# 3   12/9/2016 17:00      0.000000  6285.435059  6393.759277  6471.579590
# 4   12/1/2017 23:00      0.000000  6698.252441  7791.966797  6547.348145
#
#    UZ_Tub_Pres  MZ_Tub_Pres  LZ_Tub_Pres    UZ_ICV_dP    MZ_ICV_dP  ...  \
# 0  7549.300293  7666.192383  7740.737793   875.580750    -6.677987  ...
# 1  8733.222656  8837.158203  8912.913086  1285.704102    10.593750  ...
# 2  8626.978516  8737.755859  8811.809570  2329.720703     1.975586  ...
# 3  6292.383301  6397.249512  6474.816895     6.656913     3.320606  ...
# 4  6356.360840  6465.707031  6543.325195  -341.891602 -1326.259766  ...
#
#    Predicted_KN_LZ  Predicted_DT_UZ  Predicted_DT_MZ  Predicted_DT_LZ  \
# 0              0.0              0.0          0.00000      3216.770264
# 1              0.0              0.0      13483.12207         0.000000
# 2              0.0              0.0       5648.76123         0.000000
# 3              0.0              0.0          0.00000         0.000000
# 4              0.0              0.0          0.00000         0.000000
#
#    Predicted_ETF_UZ  Predicted_ETF_MZ  Predicted_ETF_LZ  Predicted_ET_BO_UZ  \
# 0        417.676481       3575.927386         32.167703          402.355402
# 1          0.000000      13352.514200          0.000000            0.000000
# 2          0.000000       5647.419067          0.000000            0.000000
# 3          0.000000          0.000000          0.000000            0.000000
# 4          0.000000          0.000000          0.000000            0.000000
#
#    Predicted_ET_BO_MZ  Predicted_ET_BO_LZ
# 0         3510.507081          120.593375
# 1        13359.666220            0.000000
# 2         5647.921328            0.000000
# 3            0.000000            0.000000
# 4            0.000000            0.000000
#
# [5 rows x 46 columns]

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Uzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_ETF_UZ'], hist=False, color="b", label="Predicted UZonal Rates", ax=ax1)
plt.legend()


# save the heatmap as a file
fig.savefig("KDE plot of UZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Mzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_ETF_MZ'], hist=False, color="b", label="Predicted MZonal Rates", ax=ax1)
plt.legend()


# save the heatmap as a file
fig.savefig("KDE plot of MZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Lzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_ETF_LZ'], hist=False, color="b", label="Predicted LZonal Rates", ax=ax1)
plt.legend()


# save the heatmap as a file
fig.savefig("KDE plot of LZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Uzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_RF_UZ'], hist=False, color="b", label="Predicted UZonal Rates", ax=ax1)
plt.legend()

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Mzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_RF_MZ'], hist=False, color="b", label="Predicted MZonal Rates", ax=ax1)
plt.legend()

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Predictions['Norm_Lzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Predictions['Predicted_RF_LZ'], hist=False, color="b", label="Predicted LZonal Rates", ax=ax1)
plt.legend()

# %%
fig= sns.jointplot(x='Predicted_ETF_UZ',y='Norm_Uzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
fig.savefig("Jointplot of UZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig= sns.jointplot(x='Predicted_ETF_MZ',y='Norm_Mzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
fig.savefig("Jointplot of MZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig= sns.jointplot(x='Predicted_ETF_LZ',y='Norm_Lzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
fig.savefig("Jointplot of LZ.jpg",
            format='jpeg',
            dpi=500,
            bbox_inches='tight')

# %%
fig= sns.jointplot(x='Predicted_RFF_UZ',y='Norm_Uzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
#fig.savefig("Jointplot of Deep Ensemble Super Learner Regressor.jpg",
#            format='jpeg',
#            dpi=100,
#            bbox_inches='tight')

# %%
fig= sns.jointplot(x='Predicted_RFF_MZ',y='Norm_Mzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
#fig.savefig("Jointplot of Deep Ensemble Super Learner Regressor.jpg",
#            format='jpeg',
#            dpi=100,
#            bbox_inches='tight')

# %%
fig= sns.jointplot(x='Predicted_RFF_LZ',y='Norm_Lzonal_Rate',data=Predictions,kind='reg', color='g')
#plt.gca().set(ylim=(0,80000), xlim=(0,80000))

# save the heatmap as a file
#fig.savefig("Jointplot of Deep Ensemble Super Learner Regressor.jpg",
#            format='jpeg',
#            dpi=100,
#            bbox_inches='tight')

# %%
Deploy = pd.read_csv(r"C:\Users\Daniel\OneDrive - Universiti Teknologi PETRONAS\Desktop\Book\Smart well injection\Smart Injection\WI_pred.csv")
Deploy.head()
# Out:
#    Unnamed: 0           Date      WI_Rate  UZ_Ann_Pres  MZ_Ann_Pres  \
# 0           0  1/8/2016 0:00  84797.63281  6346.441895  6415.320801
# 1           1  1/8/2016 1:00  84880.31250  6346.474121  6415.352539
# 2           2  1/8/2016 2:00  84804.59375  6346.500977  6415.385254
# 3           3  1/8/2016 3:00  84728.88281  6346.516113  6415.399902
# 4           4  1/8/2016 4:00  84653.16406  6346.517578  6415.424805
#
#    LZ_Ann_Pres  UZ_Tub_Pres  MZ_Tub_Pres  LZ_Tub_Pres  UZ_ICV_dP   ...  \
# 0  6468.405762  6346.523926  6450.257324  6529.002441   -0.220879  ...
# 1  6468.445313  6346.555176  6450.287598  6529.039551   -0.219371  ...
# 2  6468.471680  6346.579590  6450.314941  6529.063477   -0.216536  ...
# 3  6468.486328  6346.592285  6450.331543  6529.080566   -0.219699  ...
# 4  6468.489746  6346.592773  6450.338379  6529.084473   -0.218044  ...
#
#         THT  Annulus_Pressure          THP    Tubing_Dp  Norm_Uzonal_Rate  \
# 0  3.888920       5892.671429  2376.399882  3516.271547               0.0
# 1  3.946249       5909.583735  2383.830180  3525.753555               0.0
# 2  4.003609       5919.674540  2392.431272  3527.243268               0.0
# 3  4.060938       5932.487370  2400.584895  3531.902476               0.0
# 4  4.118267       5940.982933  2410.476247  3530.506686               0.0
#
#    Norm_Mzonal_Rate  Norm_Lzonal_Rate  Predicted_UZ  Predicted_MZ  \
# 0               0.0       84797.63281           0.0           0.0
# 1               0.0       84880.31250           0.0           0.0
# 2               0.0       84804.59375           0.0           0.0
# 3               0.0       84728.88281           0.0           0.0
# 4               0.0       84653.16406           0.0           0.0
#
#    Predicted_LZ
# 0   84797.63281
# 1   84880.31250
# 2   84804.59375
# 3   84728.88281
# 4   84653.16406
#
# [5 rows x 29 columns]

# %%
Deploy.shape
# Out:
# (3767, 29)

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Deploy['Norm_Uzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Deploy['Predicted_UZ'], hist=False, color="b", label="Predicted UZonal Rates", ax=ax1)
# Out:
# <AxesSubplot: xlabel='Predicted_UZ', ylabel='Density'>

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Deploy['Norm_Mzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Deploy['Predicted_MZ'], hist=False, color="b", label="Predicted MZonal Rates", ax=ax1)
# Out:
# <AxesSubplot: xlabel='Predicted_MZ', ylabel='Density'>

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax1 = sns.distplot(Deploy['Norm_Lzonal_Rate'], hist=False, color="r", label="Actual")

sns.distplot(Deploy['Predicted_LZ'], hist=False, color="b", label="Predicted LZonal Rates", ax=ax1)
# Out:
# <AxesSubplot: xlabel='Predicted_LZ', ylabel='Density'>
